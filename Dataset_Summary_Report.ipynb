# %% [markdown]
# # Dataset Summary Report
#
# ### Day 7 Assignment
#
# This notebook uses Python and Pandas to load, explore, and summarize a CSV dataset. It demonstrates dataset inspection, structure, data types, descriptive statistics, and identification of missing values.

# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6250b8f6-9ee1-4575-bd3a-0eb568872412" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6250b8f6-9ee1-4575-bd3a-0eb568872412">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Day7_Student_Dataset.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# ## 1. Dataset Overview

# %%
df
# Out:
#     Student_ID           Name  Age            Course  Marks  \
# 0         1001   Aarav Sharma   19      Data Science   87.0
# 1         1002      Zoya Khan   20                AI   92.0
# 2         1003    Rohan Mehta   18  Computer Science   76.0
# 3         1004   Ananya Singh   21      Data Science   81.0
# 4         1005      Kabir Ali   19                AI   69.0
# 5         1006   Ishita Gupta   20  Computer Science   88.0
# 6         1007   Aditya Verma   22      Data Science   95.0
# 7         1008     Sara Ahmed   19                AI   73.0
# 8         1009     Arjun Nair   18  Computer Science   84.0
# 9         1010     Mehak Bhat   21      Data Science   79.0
# 10        1011  Vivaan Kapoor   20                AI   91.0
# 11        1012      Aisha Mir   19  Computer Science   68.0
# 12        1013      Rahul Das   23      Data Science   72.0
# 13        1014     Sana Malik   18                AI   89.0
# 14        1015    Karan Joshi   20  Computer Science   77.0
# ...

# %% [markdown]
# ## 2. First Five Rows

# %%
df.head()
# Out:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow

# %%
df.head(10)
# Out:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
# 5        1006  Ishita Gupta   20  Computer Science   88.0
# 6        1007  Aditya Verma   22      Data Science   95.0
# 7        1008    Sara Ahmed   19                AI   73.0
# 8        1009    Arjun Nair   18  Computer Science   84.0
# 9        1010    Mehak Bhat   21      Data Science   79.0
#
#    Attendance_Percentage       City
# 0                   91.0   Srinagar
# 1                   95.0      Delhi
# 2                   82.0     Mumbai
# 3                   88.0   Srinagar
# 4                   76.0    Lucknow
# 5                   93.0  Bengaluru
# 6                   97.0       Pune
# ...

# %% [markdown]
# ## 3. Last Five Rows

# %%
df.tail()
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
#     Attendance_Percentage       City
# 20                   78.0      Delhi
# 21                   98.0   Srinagar
# 22                   83.0       Pune
# 23                   88.0  Hyderabad
# 24                   84.0    Kolkata

# %% [markdown]
# ## 4. Random Sample of the Dataset

# %%
df.sample(5)
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 15        1016   Hiba Sheikh   21      Data Science   94.0
# 9         1010    Mehak Bhat   21      Data Science   79.0
# 12        1013     Rahul Das   23      Data Science   72.0
# 5         1006  Ishita Gupta   20  Computer Science   88.0
# 13        1014    Sana Malik   18                AI   89.0
#
#     Attendance_Percentage       City
# 15                   96.0   Srinagar
# 9                    90.0   Srinagar
# 12                   81.0    Kolkata
# 5                    93.0  Bengaluru
# 13                   92.0        NaN

# %% [markdown]
# ## 5. Dataset Shape

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Shape of dataset:", df.shape)
# Out:
# Number of rows: 25
# Number of columns: 7
# Shape of dataset: (25, 7)

# %% [markdown]
# ## 6. Dataset Columns

# %%
print("Column names:")
print(df.columns)
# Out:
# Column names:
# Index(['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage',
#        'City'],
#       dtype='object')

# %%
print(list(df.columns))
# Out:
# ['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage', 'City']

# %% [markdown]
# ## 7. Dataset Index

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %% [markdown]
# ## 8. Data Types

# %%
print(df.dtypes)
# Out:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object

# %% [markdown]
# ## 9. Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     int64
#  1   Name                   25 non-null     object
#  2   Age                    25 non-null     int64
#  3   Course                 25 non-null     object
#  4   Marks                  24 non-null     float64
#  5   Attendance_Percentage  24 non-null     float64
#  6   City                   24 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# ## 10. Descriptive Statistics

# %%
df.describe()
# Out:
#         Student_ID        Age      Marks  Attendance_Percentage
# count    25.000000  25.000000  24.000000              24.000000
# mean   1013.000000  20.000000  82.250000              87.083333
# std       7.359801   1.414214   8.689074               7.252686
# min    1001.000000  18.000000  68.000000              72.000000
# 25%    1007.000000  19.000000  75.500000              82.750000
# 50%    1013.000000  20.000000  82.500000              88.000000
# 75%    1019.000000  21.000000  89.250000              92.250000
# max    1025.000000  23.000000  96.000000              98.000000

# %% [markdown]
# ## 11. Missing Values

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64

# %%
total_missing = df.isnull().sum().sum()

print("Total missing values:", total_missing)
# Out:
# Total missing values: 3

# %% [markdown]
# ## 12. Duplicate Rows

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("Unique values in each column:")
print(df.nunique())
# Out:
# Unique values in each column:
# Student_ID               25
# Name                     25
# Age                       6
# Course                    3
# Marks                    24
# Attendance_Percentage    22
# City                     13
# dtype: int64

# %% [markdown]
# ## 13. Basic Observations
#
# - The dataset contains 25 rows representing individual records.
# - The dataset contains 7 columns representing different features.
# - The columns contain different data types such as int64,float64,object data.
# - The `head()` and `tail()` functions were used to inspect the beginning and end of the dataset.
# - Random samples were viewed using the `sample()` function.
# - Descriptive statistics were generated using `describe()`.
# - Missing values were checked using `isnull().sum()`.
# - The dataset structure and data types were examined using `info()` and `dtypes`.

# %%
print("===== DATASET SUMMARY =====")

print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])

print("\nColumns:")
print(list(df.columns))

print("\nData Types:")
print(df.dtypes)

print("\nTotal Missing Values:", df.isnull().sum().sum())

print("Duplicate Rows:", df.duplicated().sum())
# Out:
# ===== DATASET SUMMARY =====
# Number of Rows: 25
# Number of Columns: 7
#
# Columns:
# ['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage', 'City']
#
# Data Types:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object
#
# Total Missing Values: 3
# Duplicate Rows: 0
